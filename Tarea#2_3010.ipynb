# %% [markdown]
# <a href="https://colab.research.google.com/github/FernadoEscobar/edd_3010_2021/blob/master/Tarea%232_3010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
datos="""
1,2,      1,   14,          29,45,5,        58,56, 10,     29,     14,      88,           17,4,3,1,7,         12,            10,

2,        23,               5, 8, 44,        2, 2,             13,             5,9,10,16,  98,  76,      47,     1,1,3,         2,

3,       87,       15,11,9,      7,90,97,           21,3,4,1,     8,   88,    74,         32, 34,    43, 17,        77, 93,

4,46,8,1,6,2,         10,37,84,     4,5,9,10,            2,         6 ,3   1,1 ,1,    8,   4,20,  33,  23,       18, 45,
     
55, 3, 2,      29,     58,    83,9, 17, 1,    43, 20,          93,     31,        46,43, 77,           8,44,45, 17,          62,

6,       74, 13, 44,          18, 45,                11,   93, 2,   1, 1 ,1,        25, 1,        42,  18,     22,              44,   52,

7,    88, 93,    6, 54, 2, 8, 1,        41, 86, 79,        33, 48,9,             32, 63,18,7,         33,2,1,     16,11, 7,

8, 0,  22,    17,30,6, 2,         12, 47,  37,     34,   85,       47,    33,  2,  6,      8, 4, 5,   29,    30, 42,      77, 2,

9,    2,3,4,    1,1,      3,6,   7,7,8,  9,      5, 1,      3, 4, 9,    10,           12,    3, 1,     5,    6,    22,11,     0,  2,

1,0,     2,55,      9,  3,     55,    23,1,6,      9,    4,   5,     3,3,2,  1,      3,8,      1,   6,       10,      0,   1,5,1,      3
"""
datos.replace('\n', ' ').replace(' ','')
# Out:
# '1,2,1,14,29,45,5,58,56,10,29,14,88,17,4,3,1,7,12,10,2,23,5,8,44,2,2,13,5,9,10,16,98,76,47,1,1,3,2,3,87,15,11,9,7,90,97,21,3,4,1,8,88,74,32,34,43,17,77,93,4,46,8,1,6,2,10,37,84,4,5,9,10,2,6,31,1,1,8,4,20,33,23,18,45,55,3,2,29,58,83,9,17,1,43,20,93,31,46,43,77,8,44,45,17,62,6,74,13,44,18,45,11,93,2,1,1,1,25,1,42,18,22,44,52,7,88,93,6,54,2,8,1,41,86,79,33,48,9,32,63,18,7,33,2,1,16,11,7,8,0,22,17,30,6,2,12,47,37,34,85,47,33,2,6,8,4,5,29,30,42,77,2,9,2,3,4,1,1,3,6,7,7,8,9,5,1,3,4,9,10,12,3,1,5,6,22,11,0,2,1,0,2,55,9,3,55,23,1,6,9,4,5,3,3,2,1,3,8,1,6,10,0,1,5,1,3'

# %%
reglon_1=[1,2,1,14,29,45,5,58,56,10,29,14,88,17,4,3,1,7,12,10]
reglon_2=[2,23,5,8,44,2,2,13,5,9,10,16,98,76,47,1,1,3,2]
reglon_3=[3,87,15,11,9,7,90,97,21,3,4,1,8,88,74,32,34,43,17,77,93]
reglon_4=[4,46,8,1,6,2,10,37,84,4,5,9,10,2,6,31,1,1,8,4,20,33,23,18,45]
reglon_5=[55,3,2,29,58,83,9,17,1,43,20,93,31,46,43,77,8,44,45,17,62]
reglon_6=[6,74,13,44,18,45,11,93,2,1,1,1,25,1,42,18,22,44,52]
reglon_7=[7,88,93,6,54,2,8,1,41,86,79,33,48,9,32,63,18,7,33,2,1,16,11,7]
reglon_8=[8,0,22,17,30,6,2,12,47,37,34,85,47,33,2,6,8,4,5,29,30,42,77,2]
reglon_9=[9,2,3,4,1,1,3,6,7,7,8,9,5,1,3,4,9,10,12,3,1,5,6,22,11,0,2]
reglon_10=[1,0,2,55,9,3,55,23,1,6,9,4,5,3,3,2,1,3,8,1,6,10,0,1,5,1,3]
print(sum(reglon_1))
print(sum(reglon_2))
print(sum(reglon_3))
print(sum(reglon_4))
print(sum(reglon_5))
print(sum(reglon_6))
print(sum(reglon_7))
print(sum(reglon_8))
print(sum(reglon_9))
print(sum(reglon_10))
# Out:
# 406
# 367
# 814
# 418
# 786
# 513
# 745
# 585
# 154
# 220

# %%
def sumalista(listaNumeros):
    laSuma = 0
    for i in listaNumeros:
        laSuma = laSuma + i
    return laSuma

print(sumalista([1,2,1,14,29,45,5,58,56,10,29,14,88,17,4,3,1,7,12,10,2,23,5,8,44,2,2,13,5,9,10,16,98,76,47,1,1,3,2,3,87,15,11,9,7,90,97,21,3,4,1,8,88,74,32,34,43,17,77,93,4,46,8,1,6,2,10,37,84,4,5,9,10,2,6,31,1,1,8,4,20,33,23,18,45,55,3,2,29,58,83,9,17,1,43,20,93,31,46,43,77,8,44,45,17,62,6,74,13,44,18,45,11,93,2,1,1,1,25,1,42,18,22,44,52,7,88,93,6,54,2,8,1,41,86,79,33,48,9,32,63,18,7,33,2,1,16,11,7,8,0,22,17,30,6,2,12,47,37,34,85,47,33,2,6,8,4,5,29,30,42,77,2,9,2,3,4,1,1,3,6,7,7,8,9,5,1,3,4,9,10,12,3,1,5,6,22,11,0,2,1,0,2,55,9,3,55,23,1,6,9,4,5,3,3,2,1,3,8,1,6,10,0,1,5,1,3]))
# Out:
# 5008
